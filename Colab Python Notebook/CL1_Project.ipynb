# %%
import nltk
from nltk.corpus import indian
from nltk.tag import tnt
import string
import re

# %%
text="एक बार हवा और सूरज में बहस छिड़ गई। हवा ने सूरज से कहा- मैं तुमसे अधिक बलवान हूँ। सूरज ने हवा से कहा-मुझमें तुमसे ज्यादा ताकत है। इतने में हवा की नज़र एक आदमी पर पड़ी। हवा ने कहा-इस तरह बहस करने से कोई फ़ायदा नहीं है। जो इस आदमी का कोट उतरवा दे, वही ज्यादा बलवान है।सरज हवा की बात मान गया। उसने कहा-ठीक है। दिखाओ अपनी ताकत। हवा ने अपनी ताकत दिखानी। शुरू की। आदमी की टोपी उड़ गई। कोट उसने अपने दोनों हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए। हवा और ज़ोर से चलने लगी। अंत में आदमी नीचे ही गिर पड़ा, पर कोट उसके शरीर पर ही रहा। अब हवा थक गई थी।सूरज ने कहा- हवा, अब तुम मेरी ताकत देखो। सूरज तपने लगा। आदमी ने कोट के बटन खोल दिए। सूरज की गर्मी और बढ़ी। आदमी ने कोट उतार दिया और उसे हाथ में लेकर चलने लगा। सूरज ने कहा-देखी मेरी ताकत? उतरवा दिया न कोट? हवा ने सूरज को नमस्कार किया और कहा-मान गई तुम्हारी ताकत को।"

# %%
nltk.download('punkt')
# Downloading Indian Languages Corpora which consists Hindi, Bangla, Marathi and Telugu corpus respectively
nltk.download("indian")

# Downloading Tokenizers
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
class MyClass:
    def __init__(self, text):
        self.text = text

    def clean_text(self):
        text = self.text
        text = re.sub(r'(\d+)',r'',text)
        text = text.replace(u'।',' । ')
        text = text.replace(u',','')
        text = text.replace(u'"','')
        text = text.replace(u'(','')
        text = text.replace(u')','')
        text = text.replace(u'"','')
        text = text.replace(u':','')
        text = text.replace(u"'",'')
        text = text.replace(u"‘",'')
        text = text.replace(u"’",'')
        text = text.replace(u"''",'')
        text = text.replace(u".",'')
        text = text.replace(u"!",'')
        text = text.replace(u'“','')
        text = text.replace(u'”','')
        self.text = text

my_obj = MyClass(text)
my_obj.clean_text()
cleaned_text = my_obj.text
print(cleaned_text)
# Out:
# एक बार हवा और सूरज में बहस छिड़ गई ।  हवा ने सूरज से कहा- मैं तुमसे अधिक बलवान हूँ ।  सूरज ने हवा से कहा-मुझमें तुमसे ज्यादा ताकत है ।  इतने में हवा की नज़र एक आदमी पर पड़ी ।  हवा ने कहा-इस तरह बहस करने से कोई फ़ायदा नहीं है ।  जो इस आदमी का कोट उतरवा दे वही ज्यादा बलवान है । सरज हवा की बात मान गया ।  उसने कहा-ठीक है ।  दिखाओ अपनी ताकत ।  हवा ने अपनी ताकत दिखानी ।  शुरू की ।  आदमी की टोपी उड़ गई ।  कोट उसने अपने दोनों हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए ।  हवा और ज़ोर से चलने लगी ।  अंत में आदमी नीचे ही गिर पड़ा पर कोट उसके शरीर पर ही रहा ।  अब हवा थक गई थी । सूरज ने कहा- हवा अब तुम मेरी ताकत देखो ।  सूरज तपने लगा ।  आदमी ने कोट के बटन खोल दिए ।  सूरज की गर्मी और बढ़ी ।  आदमी ने कोट उतार दिया और उसे हाथ में लेकर चलने लगा ।  सूरज ने कहा-देखी मेरी ताकत? उतरवा दिया न कोट? हवा ने सूरज को नमस्कार किया और कहा-मान गई तुम्हारी ताकत को ।

# %%
from nltk.corpus import indian
from nltk.tag import tnt

# %%
# !pip install --upgrade stanza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stanza
#   Downloading stanza-1.5.0-py3-none-any.whl (802 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.5/802.5 kB 10.9 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.5.1.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 25.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.22.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from stanza) (1.16.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351210 sha256=5a0f9c3bda4895f41ae9dff6848529167c529d6246069e10a21d792f9212af46
#   Stored in directory: /root/.cache/pip/wheels/51/92/44/e2ef13f803aa08711819357e6de0c5fe67b874671141413565
# Successfully built emoji
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.5.1 stanza-1.5.0

# %%
import stanza
stanza.download('hi')
nlp = stanza.Pipeline(lang='hi', processors='tokenize,pos')
doc = nlp(cleaned_text)
output_list = []
dict_list = []
for sent in doc.sentences :
  for word in sent.words:
    word_info = (
        word.text,
        word.upos,
        word.xpos,
        word.feats
    )
# List of dictionary for dependency parsing
    dict = {
        'text' : word.text,
        'upos' : word.upos,
        'xpos' : word.xpos,
        'feats' : word.feats if word.feats else "_"
    }
    output_list.append(word_info)
    dict_list.append(dict)
o1 = []
o1.append(dict_list)
print (output_list)
# print (o1)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: hi (Hindi) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-hi/resolve/v1.5.0/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# [('एक', 'NUM', 'QC', 'NumType=Card'), ('बार', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('और', 'CCONJ', 'CC', None), ('सूरज', 'NOUN', 'NN', 'Case=Acc|Gender=Masc|Number=Sing|Person=3'), ('में', 'ADP', 'PSP', 'AdpType=Post'), ('बहस', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('छिड़', 'VERB', 'VM', 'Number=Sing|Voice=Act'), ('गई', 'AUX', 'VAUX', 'Aspect=Perf|Gender=Fem|Number=Sing|VerbForm=Part'), ('।', 'PUNCT', 'SYM', None), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('ने', 'ADP', 'PSP', 'AdpType=Post'), ('सूरज', 'PROPN', 'NNP', 'Case=Acc|Gender=Masc|Number=Sing|Person=3'), ('से', 'ADP', 'PSP', 'AdpType=Post'), ('कहा-', 'VERB', 'VM', 'Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act'), ('मैं', 'PRON', 'PRP', 'Case=Nom|Number=Sing|Person=1|PronType=Prs'), ('तुमसे', 'PRON', 'PRP', 'Case=Acc,Ins|Number=Plur|Person=1|PronType=Prs'), ('अधिक', 'DET', 'QF', 'PronType=Ind'), ('बलवान', 'ADJ', 'JJ', None), ('हूँ', 'AUX', 'VM', 'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act'), ('।', 'PUNCT', 'SYM', None), ('सूरज', 'PROPN', 'NNP', 'Case=Acc|Gender=Masc|Number=Sing|Person=3'), ('ने', 'ADP', 'PSP', 'AdpType=Post'), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('से', 'ADP', 'PSP', 'AdpType=Post'), ('कहा-मुझमें', 'ADV', 'RB', None), ('तुमसे', 'PRON', 'PRP', 'Case=Acc,Dat|Number=Sing|Person=1|PronType=Prs'), ('ज्यादा', 'DET', 'QF', 'PronType=Ind'), ('ताकत', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('है', 'AUX', 'VM', 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act'), ('।', 'PUNCT', 'SYM', None), ('इतने', 'DET', 'QF', 'Case=Acc|Gender=Masc|Number=Sing'), ('में', 'ADP', 'PSP', 'AdpType=Post'), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('की', 'ADP', 'PSP', 'AdpType=Post|Case=Nom|Gender=Fem|Number=Sing'), ('नज़र', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('एक', 'NUM', 'QC', 'NumType=Card'), ('आदमी', 'NOUN', 'NN', 'Case=Acc|Gender=Masc|Number=Sing|Person=3'), ('पर', 'ADP', 'PSP', 'AdpType=Post'), ('पड़ी', 'VERB', 'VM', 'Aspect=Perf|Gender=Fem|Number=Sing|VerbForm=Part|Voice=Act'), ('।', 'PUNCT', 'SYM', None), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('ने', 'ADP', 'PSP', 'AdpType=Post'), ('कहा-इस', 'DET', 'DEM', 'Case=Acc|Number=Sing|Person=3|PronType=Dem'), ('तरह', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('बहस', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('करने', 'VERB', 'VM', 'Case=Acc|VerbForm=Inf'), ('से', 'ADP', 'PSP', 'AdpType=Post'), ('कोई', 'PRON', 'PRP', 'Case=Nom|Number=Sing|Person=3|PronType=Prs'), ('फ़ायदा', 'NOUN', 'NN', 'Case=Nom|Gender=Masc|Number=Sing|Person=3'), ('नहीं', 'PART', 'NEG', 'Polarity=Neg|PronType=Neg'), ('है', 'VERB', 'VM', 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act'), ('।', 'PUNCT', 'SYM', None), ('जो', 'PRON', 'PRP', 'Case=Nom|Number=Sing|Person=3|PronType=Prs'), ('इस', 'DET', 'DEM', 'Case=Acc|Number=Sing|Person=3|PronType=Dem'), ('आदमी', 'NOUN', 'NN', 'Case=Acc|Gender=Masc|Number=Sing|Person=3'), ('का', 'ADP', 'PSP', 'AdpType=Post|Case=Nom|Gender=Masc|Number=Sing'), ('कोट', 'NOUN', 'NN', 'Case=Nom|Gender=Masc|Number=Sing|Person=3'), ('उतरवा', 'VERB', 'VM', 'Voice=Act'), ('दे', 'AUX', 'VAUX', None), ('वही', 'PRON', 'PRP', 'Case=Nom|Number=Sing|Person=3|PronType=Prs'), ('ज्यादा', 'DET', 'QF', 'PronType=Ind'), ('बलवान', 'ADJ', 'JJ', None), ('है', 'AUX', 'VM', 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act'), ('।', 'PUNCT', 'SYM', None), ('सरज', 'PROPN', 'NNP', 'Case=Nom|Gender=Masc|Number=Sing|Person=3'), ('हवा', 'NOUN', 'NN', 'Case=Acc|Gender=Fem|Number=Sing|Person=3'), ('की', 'ADP', 'PSP', 'AdpType=Post|Case=Nom|Gender=Fem|Number=Sing'), ('बात', 'NOUN', 'NN', 'Case=Nom|Gender=Fem|Number=Sing|Person=3'), ('मान', 'VERB', 'VM', 'Number=Sing|Voice=Act'), ('गया', 'AUX', 'VAUX' ...

# %%
# DEPENDENCY PARSING
import stanza
from stanza.models.common.doc import Document

nlp = stanza.Pipeline(lang='hi', processors='depparse', depparse_pretagged=True)
pretagged_doc = Document(o1)
doc = nlp(pretagged_doc)

# print (doc)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | depparse  | hdtb    |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %%
# NOMINATIVE CASE
str=""
# value1 = 0
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+500):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if key == 'Case' and value == 'Nom' and output_list[i][1]=='NOUN'or key == 'Case' and value == 'Nom' and output_list[i][1]=='PRON':
                      if flag == 0 :
                        if marker == iter :
                          temp="कौन"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1
        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)
          # value1 = value1 + 1;
# print(value1)
# Out:
# एक कौन हवा और सूरज में बहस छिड़ गई ?
# एक बार हवा और सूरज में कौन छिड़ गई ?
# हवा ने सूरज से कहा- कौन तुमसे अधिक बलवान हूँ ?
# सूरज ने हवा से कहा-मुझमें तुमसे ज्यादा कौन है ?
# इतने में हवा की कौन एक आदमी पर पड़ी ?
# हवा ने कहा-इस कौन बहस करने से कोई फ़ायदा नहीं है ?
# हवा ने कहा-इस तरह कौन करने से कोई फ़ायदा नहीं है ?
# हवा ने कहा-इस तरह बहस करने से कौन फ़ायदा नहीं है ?
# हवा ने कहा-इस तरह बहस करने से कोई कौन नहीं है ?
# कौन इस आदमी का कोट उतरवा दे वही ज्यादा बलवान है ?
# जो इस आदमी का कौन उतरवा दे वही ज्यादा बलवान है ?
# जो इस आदमी का कोट उतरवा दे कौन ज्यादा बलवान है ?
# सरज हवा की कौन मान गया ?
# दिखाओ कौन ताकत ?
# दिखाओ अपनी कौन ?
# हवा ने कौन ताकत दिखानी ?
# हवा ने अपनी कौन दिखानी ?
# कौन की ?
# आदमी की कौन उड़ गई ?
# कोट उसने अपने दोनों हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के कौन बंद कर लिए ?
# कौन और ज़ोर से चलने लगी ?
# अंत में कौन नीचे ही गिर पड़ा पर कोट उसके शरीर पर ही रहा ?
# अंत में आदमी नीचे ही गिर पड़ा पर कौन उसके शरीर पर ही रहा ?
# कौन हवा थक गई थी ?
# अब कौन थक गई थी ?
# सूरज ने कहा- कौन अब तुम मेरी ताकत देखो ?
# सूरज ने कहा- हवा कौन तुम मेरी ताकत देखो ?
# सूरज ने कहा- हवा अब कौन मेरी ताकत देखो ?
# सूरज ने कहा- हवा अब तुम मेरी कौन देखो ?
# आदमी ने कोट के कौन खोल दिए ?
# सूरज की कौन और बढ़ी ?
# आदमी ने कौन उतार दिया और उसे हाथ में लेकर चलने लगा ?
# सूरज ने कहा-देखी मेरी कौन ?
# उतरवा दिया न कौन ?
# हवा ने सूरज को कौन किया और कहा-मान गई तुम्हारी ताकत को ?

# %%
# ACCUSATIVE
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if key == 'Case' and value == 'Acc' and output_list[i][1]=='NOUN' or key == 'Case' and value == 'Acc' and output_list[i][1]=='PRON':
                      if flag == 0 :
                        if marker == iter :
                          temp="किस"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)
# Out:
# एक बार किस और सूरज में बहस छिड़ गई ?
# एक बार हवा और किस में बहस छिड़ गई ?
# किस ने सूरज से कहा- मैं तुमसे अधिक बलवान हूँ ?
# सूरज ने किस से कहा-मुझमें तुमसे ज्यादा ताकत है ?
# इतने में किस की नज़र एक आदमी पर पड़ी ?
# इतने में हवा की नज़र एक किस पर पड़ी ?
# किस ने कहा-इस तरह बहस करने से कोई फ़ायदा नहीं है ?
# जो इस किस का कोट उतरवा दे वही ज्यादा बलवान है ?
# सरज किस की बात मान गया ?
# किस ने अपनी ताकत दिखानी ?
# किस की टोपी उड़ गई ?
# कोट उसने किस दोनों हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए ?
# कोट उसने अपने दोनों किस से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए ?
# कोट उसने अपने दोनों हाथों से किस से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए ?
# कोट उसने अपने दोनों हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी किस के बटन बंद कर लिए ?
# हवा और किस से चलने लगी ?
# किस में आदमी नीचे ही गिर पड़ा पर कोट उसके शरीर पर ही रहा ?
# अंत में आदमी नीचे ही गिर पड़ा पर कोट उसके किस पर ही रहा ?
# किस ने कोट के बटन खोल दिए ?
# आदमी ने किस के बटन खोल दिए ?
# किस ने कोट उतार दिया और उसे हाथ में लेकर चलने लगा ?
# आदमी ने कोट उतार दिया और उसे किस में लेकर चलने लगा ?
# किस ने सूरज को नमस्कार किया और कहा-मान गई तुम्हारी ताकत को ?
# हवा ने किस को नमस्कार किया और कहा-मान गई तुम्हारी ताकत को ?
# हवा ने सूरज को नमस्कार किया और कहा-मान गई तुम्हारी किस को ?

# %%
# NUMBER
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if output_list[i][1]=='NUM':

                      if flag == 0 :
                        if marker == iter :
                          temp="कितने"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)
# Out:
# कितने बार हवा और सूरज में बहस छिड़ गई ?
# इतने में हवा की नज़र कितने आदमी पर पड़ी ?
# कोट उसने अपने कितने हाथों से शरीर से लपेटे रखा और जल्दी-जल्दी कोट के बटन बंद कर लिए ?

# %%
# ADJECTIVE
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  new = 0;
                  # print(pair)
                  key, value = pair.split('=')
                  if key == 'Gender' and value == 'Masc' and output_list[i][1] == 'ADJ':
                      new = 1;
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसा"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  if output_list[i][1]=='ADJ' and key == 'Gender' and value == 'Fem':
                      new = 1;
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसी"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  if output_list[i][1]=='ADJ' and new == 0:
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसे"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)

# %%
import stanza
from stanza.models.common.doc import Document

nlp = stanza.Pipeline(lang='hi', processors='depparse', depparse_pretagged=True)
pretagged_doc = Document([[{'id': 1, 'text': 'Test', 'lemma': 'Test', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing'}, {'id': 2, 'text': 'sentence', 'lemma': 'sentence', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing'}, {'id': 3, 'text': '.', 'lemma': '.', 'upos': 'PUNCT', 'xpos': '.'}]])
doc = nlp(pretagged_doc)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | depparse  | hdtb    |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %%
print(*[f'id: {word.id}\tword: {word.text}\thead id: {word.head}\thead: {sent.words[word.head-1].text if word.head > 0 else "root"}\tdeprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# id: 1	word: Test	head id: 2	head: sentence	deprel: nmod
# id: 2	word: sentence	head id: 0	head: root	deprel: root
# id: 3	word: .	head id: 2	head: sentence	deprel: punct

# %%
import nltk
from nltk.corpus import indian
from nltk.tag import tnt
import string
import re
nltk.download('punkt')
# Downloading Indian Languages Corpora which consists Hindi, Bangla, Marathi and Telugu corpus respectively
nltk.download("indian")
# Downloading Tokenizers
nltk.download("punkt")
from nltk.corpus import indian
from nltk.tag import tnt
# !pip install --upgrade stanza

#TEXT

text = "प्रस्तुत कहानी एक शेखीबाज (अभिमानी ) मक्खी की है। एक जंगल में एक शेर अपना भोजन करके आराम से सो रहा था। वह कई दिनों से नहाया नहीं था। तब एक मक्खी उडती हुई आई और उसके कान मे भिन्न भिन्न करने लगी।  शेर को इन आवाज से नींद नहीं आ रही थी। वह गुस्सा हो गया और मक्खी को भाग जाने के लिए कहा। वह मक्खी बडी घमंडी थी। उसने जंगल के राजा शेर को लड़ने की चुनौती दे दी। तभी शेर को गुस्सा आ गया। उसने कान के पास पंजा मारा, लेकिन मक्खी उड़ गयी , और शेर का कान छिल गया।  इस प्रकार खुद पर प्रहार करने के कारण शेर  स्वयं ही घायल हो जाता और मक्खी उड़ जाती। अंत में शेर थक गया और उसने मक्खी के आगे हाथ जोड़ कर कहा कि तुम जीती। इस प्रकार मक्खी शेर को हरा कर अपने घमंड में चूर हो गयी। आगे जाकर उसे रास्ते में एक हाथी मिला। हाथी को उसने प्रणाम करने को कहा। हाथी ने अपना समय बर्बाद करने के बजाय अपनी सूंढ़ को उठाया। मक्खी को प्रणाम किया और आगे बढ़ गया। लोमड़ी यह सब दूर से देख रही थी। आगे मक्खी ने उसे भी प्रणाम करने को कहा। लोमड़ी चालाक थी। वह मक्खी को प्रणाम करके  बोली कि आप धन्य हो। लेकिन मकड़ी तो आपको गाली दे रही है। आप उसकी खबर ले लो। यह सुनकर मक्खी मकड़ी के पास गई। वह मकड़ी की ओर झपटी और मकड़ी के बनाये जाल में फँस गयी। "

#FILTER TEXT

class MyClass:
    def __init__(self, text):
        self.text = text

    def clean_text(self):
        text = self.text
        text = re.sub(r'(\d+)',r'',text)
        text = text.replace(u'।',' । ')
        text = text.replace(u',','')
        text = text.replace(u'"','')
        text = text.replace(u'(','')
        text = text.replace(u')','')
        text = text.replace(u'"','')
        text = text.replace(u':','')
        text = text.replace(u"'",'')
        text = text.replace(u"‘",'')
        text = text.replace(u"’",'')
        text = text.replace(u"''",'')
        text = text.replace(u".",'')
        text = text.replace(u"!",'')
        text = text.replace(u'“','')
        text = text.replace(u'”','')
        self.text = text

my_obj = MyClass(text)
my_obj.clean_text()
cleaned_text = my_obj.text
# print(cleaned_text)

import stanza
stanza.download('hi')
nlp = stanza.Pipeline(lang='hi', processors='tokenize,pos')
doc = nlp(cleaned_text)
#print(*[f'word: {word.text}\tupos: {word.upos}\txpos: {word.xpos}\tfeats: {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
output_list = []
dict_list = []
for sent in doc.sentences :
  for word in sent.words:
    word_info = (
        word.text,
        word.upos,
        word.xpos,
        word.feats
    )
# List of dictionary for dependency parsing
    dict = {
        'text' : word.text,
        'upos' : word.upos,
        'xpos' : word.xpos,
        'feats' : word.feats if word.feats else "_"
    }
    output_list.append(word_info)
    dict_list.append(dict)
o1 = []
o1.append(dict_list)
# print (output_list)
# print (o1)

#CODE TO GENERATE QUESTIONS FOR DIFFERENT CASES
# NOMINATIVE CASE
print("\n")
print("Questions made on Nominative case\n")
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+500):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  print(key)
                  print(value)
                  if key == 'Case' and value == 'Nom' and output_list[i][1]=='NOUN'or key == 'Case' and value == 'Nom' and output_list[i][1]=='PRON':
                      if flag == 0 :
                        if marker == iter :
                          temp="कौन"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1
        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)

# ACCUSATIVE
print("\n")
print("Questions made on Accusative case\n")
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if key == 'Case' and value == 'Acc' and output_list[i][1]=='NOUN' or key == 'Case' and value == 'Acc' and output_list[i][1]=='PRON':
                      if flag == 0 :
                        if marker == iter :
                          temp="क्या"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)

# NUMBER
print("\n")
print("Questions made on Cardinal Numbers\n")
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if output_list[i][1]=='NUM':

                      if flag == 0 :
                        if marker == iter :
                          temp="कितने"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)

# ADJECTIVE
print("\n")
print("Questions made on Adjective\n")
str=""
count = 0
for item in output_list:
    if isinstance(item, tuple):
        count += 1
j = 0
i = 0
num = 0
marker = 0
iter = 0
while j < count :
    str=""
    i = j
    flag = 0
    num = 0
    marker = 0
    for i in range (i, i+30):
        red = 0
        if output_list[i][1]!='PUNCT':
            properties = output_list[i][3]
            if properties is not None :
              pairs = properties.split('|')
              print(pairs)
              case_value = None
              for pair in pairs:
                  key, value = pair.split('=')
                  if output_list[i][1]=='ADJ' and key == 'Gender' and value == 'Masc':
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसा"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  elif output_list[i][1]=='ADJ' and key == 'Gender' and value == 'Fem':
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसी"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  elif output_list[i][1]=='ADJ':
                      if flag == 0 :
                        if marker == iter :
                          temp="कैसे"
                          str+=temp
                          str+=" "
                          i = i+1
                          flag = 1
                          break
                        else :
                          str += output_list[i][0]
                          str+=" "
                          i=i+1
                        marker = marker+1
                        break
                      else :
                        str += output_list[i][0]
                        str+=" "
                        i=i+1
                        num = num + 1
                        break
                  else:
                      str += output_list[i][0]
                      str+=" "
                      i=i+1
                      break
            else :
              str += output_list[i][0]
              str+=" "
              i=i+1

        else :
            break
        # print(str)
    if num == 0 :
        str += "?"
        j = i + 1
        if flag!=0:
          print(str)
        marker = 0
        iter = 0
    else :
        iter = iter + 1
        str += "?"
        if flag!=0:
          print(str)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stanza in /usr/local/lib/python3.10/dist-packages (1.5.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza) (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.22.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from stanza) (1.16.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: hi (Hindi) ...
# INFO:stanza:File exists: /root/stanza_resources/hi/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# Questions made on Nominative case
#
# Case
# Nom
# Case
# Nom
# NumType
# Card
# Case
# Acc
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Mood
# Ind
# प्रस्तुत कौन एक शेखीबाज अभिमानी मक्खी की है ?
# NumType
# Card
# Case
# Acc
# AdpType
# Post
# NumType
# Card
# Case
# Nom
# Case
# Nom
# Case
# Nom
# VerbForm
# Conv
# Case
# Acc
# AdpType
# Post
# Gender
# Masc
# Aspect
# Perf
# Gender
# Masc
# एक जंगल में एक कौन अपना भोजन करके आराम से सो रहा था ?
# NumType
# Card
# Case
# Acc
# AdpType
# Post
# NumType
# Card
# Case
# Nom
# Case
# Nom
# Case
# Nom
# VerbForm
# Conv
# Case
# Acc
# AdpType
# Post
# Gender
# Masc
# Aspect
# Perf
# Gender
# Masc
# एक जंगल में एक शेर कौन भोजन करके आराम से सो रहा था ?
# NumType
# Card
# Case
# Acc
# AdpType
# Post
# NumType
# Card
# Case
# Nom
# Case
# Nom
# Case
# Nom
# VerbForm
# Conv
# Case
# Acc
# AdpType
# Post
# Gender
# Masc
# Aspect
# Perf
# Gender
# Masc
# एक जंगल में एक शेर अपना कौन करके आराम से सो रहा था ?
# Case
# Nom
# PronType
# Ind
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# Polarity
# Neg
# Gender
# Masc
# कौन कई दिनों से नहाया नहीं था ?
# Case
# Nom
# NumType
# Card
# Case
# Nom
# Aspect
# Imp
# Aspect
# Perf
# Aspect
# Perf
# Case
# Acc,Gen
# Case
# Acc
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# कौन एक मक्खी उडती हुई आई और उसके कान मे भिन्न भिन्न करने लगी ?
# Case
# Nom
# NumType
# Card
# Case
# Nom
# Aspect
# Imp
# Aspect
# Perf
# Aspect
# Perf
# Case
# Acc,Gen
# Case
# Acc
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# तब एक कौन उडती हुई आई और उसके कान मे भिन्न भिन्न करने लगी ?
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Polarity
# Neg
# Gender
# Fem
# Aspect
# Perf
# Gender
# Fem
# शेर को इन आवाज से कौन नहीं आ रही थी ?
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Aspect
# Perf
# कौन गुस्सा हो गया और मक्खी को भाग जाने के लिए कहा ?
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Aspect
# Perf
# वह कौन हो गया और मक्खी को भाग जाने के लिए कहा ?
# Case
# Nom
# Case
# Nom
# Case
# Nom
# Gender
# Fem
# कौन मक्खी बडी घमंडी थी ?
# Case
# Nom
# Case
# Nom
# Case
# Nom
# Gender
# Fem
# वह कौन बडी घमंडी थी ?
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# उसने जंगल के कौन शेर को लड़ने की चुनौती दे दी ?
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# उसने जंगल के राजा शेर को लड़ने की कौन दे दी ?
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# कौन शेर को गुस्सा आ गया ?
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# तभी शेर को कौन आ गया ?
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# उसने कान के पास कौन मारा लेकिन मक्खी उड़ गयी और शेर का कान छिल गया ?
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# उसने कान के पास पंजा मारा लेकिन कौन उड़ गयी और शेर का कान छिल गया ?
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# उसने कान के पास पंजा मारा लेकिन मक्खी उड़ गयी और शेर का कौन छिल गया ?
# Case
# Acc
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# इस कौन खुद पर प्रहार करने के कारण शेर स्वयं ही घायल हो जाता और मक्खी उड़ जाती ?
# Case
# Acc
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# इस प्रकार खुद पर कौन करने के कारण शेर स्वयं ही घायल हो जाता और मक्खी उड़ जाती ?
# Case
# Acc
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# इस प्रकार खुद पर प्रहार करने के कारण कौन स्वयं ही घायल हो जाता और मक्खी उड़ जाती ?
# Case
# Acc
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# इस प्रकार खुद पर प्रहार करने के कारण शेर कौन ही घायल हो जाता और मक्खी उड़ जाती ?
# Case
# Acc
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# Case
# Nom
# Number
# Sing
# Aspect
# Imp
# इस प्रकार खुद पर प्रहार करने के कारण शेर स्वयं ही घायल हो जाता और कौन उड़ जाती ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Aspect
# Imp
# अंत में कौन थक गया और उसने मक्खी के आगे हाथ जोड़ कर कहा कि तुम जीती ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Aspect
# Imp
# अंत में शेर थक गया और उसने मक्खी के आगे कौन जोड़ कर कहा कि तुम जीती ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Number
# Sing
# Aspect
# Perf
# Case
# Acc,Erg
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# Case
# Nom
# Aspect
# Imp
# अंत में शेर थक गया और उसने मक्खी के आगे हाथ जोड़ कर कहा कि कौन जीती ?
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# इस कौन मक्खी शेर को हरा कर अपने घमंड में चूर हो गयी ?
# Case
# Acc
# Case
# Nom
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# इस प्रकार कौन शेर को हरा कर अपने घमंड में चूर हो गयी ?
# AdpType
# Post
# VerbForm
# Conv
# Case
# Acc,Dat
# Case
# Acc
# AdpType
# Post
# NumType
# Card
# Case
# Nom
# Aspect
# Perf
# आगे जाकर उसे रास्ते में एक कौन मिला ?
# Case
# Acc
# AdpType
# Post
# Case
# Acc,Erg
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# हाथी को उसने कौन करने को कहा ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# हाथी ने कौन समय बर्बाद करने के बजाय अपनी सूंढ़ को उठाया ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Case
# Acc
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# हाथी ने अपना कौन बर्बाद करने के बजाय अपनी सूंढ़ को उठाया ?
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# Aspect
# Perf
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# मक्खी को कौन किया और आगे बढ़ गया ?
# Case
# Nom
# Case
# Nom
# Case
# Nom
# AdpType
# Post
# AdpType
# Post
# Gender
# Fem
# Aspect
# Perf
# Gender
# Fem
# लोमड़ी यह कौन दूर से देख रही थी ?
# AdpType
# Post
# Case
# Acc
# AdpType
# Post
# Case
# Acc,Dat
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# आगे मक्खी ने उसे भी कौन करने को कहा ?
# Case
# Nom
# Gender
# Fem
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# VerbForm
# Conv
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# कौन मक्खी को प्रणाम करके बोली कि आप धन्य हो ?
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# VerbForm
# Conv
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# वह मक्खी को कौन करके बोली कि आप धन्य हो ?
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# Case
# Nom
# VerbForm
# Conv
# Aspect
# Perf
# Case
# Nom
# Number
# Sing
# वह मक्खी को प्रणाम करके बोली कि कौन धन्य हो ?
# Case
# Nom
# Case
# Acc,Dat
# Case
# Nom
# Gender
# Fem
# Aspect
# Perf
# Mood
# Ind
# लेकिन कौन तो आपको गाली दे रही है ?
# Case
# Nom
# Case
# Acc,Dat
# Case
# Nom
# Gender
# Fem
# Aspect
# Perf
# Mood
# Ind
# लेकिन मकड़ी तो आपको कौन दे रही है ?
# Case
# Nom
# Case
# Acc,Gen
# Case
# Nom
# Number
# Sing
# Mood
# Sub
# कौन उसकी खबर ले लो ?
# Case
# Nom
# Case
# Acc,Gen
# Case
# Nom
# Number
# Sing
# Mood
# Sub
# आप उसकी कौन ले लो ?
# Case
# Nom
# VerbForm
# Conv
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Aspect
# Perf
# कौन सुनकर मक्खी मकड़ी के पास गई ?
# Case
# Nom
# VerbForm
# Conv
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Aspect
# Perf
# यह सुनकर कौन मकड़ी के पास गई ?
# Case
# Nom
# Case
# Acc
# AdpType
# Post
# AdpType
# Post
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Aspect
# Perf
# Case
# Acc
# AdpType
# Post
# Number
# Sing
# Aspect
# Perf
# कौन मकड़ी की ओर झपटी और मकड़ी के बनाये जाल में फँस गयी ?
#
#
# Questions made on Accusative case
#
# प्रस्तुत कहानी एक शेखीबाज अभिमानी क्या की है ?
# एक क्या में एक शेर अपना भोजन करके आराम से सो रहा था ?
# एक जंगल में एक शेर अपना भोजन करके क्या से सो रहा था ?
# वह कई क्या से नहाया नहीं था ?
# तब एक मक्खी उडती हुई आई और उसके क्या मे भिन्न भिन्न करने लगी ?
# क्या को इन आवाज से नींद नहीं आ रही थी ?
# शेर को इन क्या से नींद नहीं आ रही थी ?
# वह गुस्सा हो गया और क्या को भाग जाने के लिए कहा ?
# उसने क्या के राजा शेर को लड़ने की चुनौती दे दी ?
# उसने जंगल के राजा क्या को लड़ने की चुनौती दे दी ?
# तभी क्या को गुस्सा आ गया ?
# उसने क्या के पास पंजा मारा लेकिन मक्खी उड़ गयी और शेर का कान छिल गया ?
# उसने कान के पास पंजा मारा लेकिन मक्खी उड़ गयी और क्या का कान छिल गया ?
# इस प्रकार क्या पर प्रहार करने के कारण शेर स्वयं ही घायल हो जाता और मक्खी उड़ जाती ?
# क्या में शेर थक गया और उसने मक्खी के आगे हाथ जोड़ कर कहा कि तुम जीती ?
# अंत में शेर थक गया और उसने क्या के आगे हाथ जोड़ कर कहा कि तुम जीती ?
# इस प्रकार मक्खी क्या को हरा कर अपने घमंड में चूर हो गयी ?
# इस प्रकार मक्खी शेर को हरा कर क्या घमंड में चूर हो गयी ?
# इस प्रकार मक्खी शेर को हरा कर अपने क्या में चूर हो गयी ?
# आगे जाकर उसे क्या में एक हाथी मिला ?
# क्या को उसने प्रणाम करने को कहा ?
# क्या ने अपना समय बर्बाद करने के बजाय अपनी सूंढ़ को उठाया ?
# हाथी ने अपना समय बर्बाद करने के बजाय क्या सूंढ़ को उठाया ?
# हाथी ने अपना समय बर्बाद करने के बजाय अपनी क्या को उठाया ?
# क्या को प्रणाम किया और आगे बढ़ गया ?
# आगे क्या ने उसे भी प्रणाम करने को कहा ?
# वह क्या को प्रणाम करके बोली कि आप धन्य हो ?
# यह सुनकर मक्खी क्या के पास गई ?
# वह क्या की ओर झपटी और मकड़ी के बनाये जाल में फँस गयी ?
# वह मकड़ी की ओर झपटी और क्या के बनाये जाल में फँस गयी ?
# वह मकड़ी की ओर झपटी और मकड़ी के बनाये क्या में फँस गयी ?
#
#
# Questions made on Cardinal Numbers
#
# प्रस्तुत कहानी कितने शेखीबाज अभिमानी मक्खी की है ?
# कितने जंगल में एक शेर अपना भोजन करके आराम से सो रहा था ?
# एक जंगल में कितने शेर अपना भोजन करके आराम से सो रहा था ?
# तब कितने मक्खी उडती हुई आई और उसके कान मे भिन्न भिन्न करने लगी ?
# आगे जाकर उसे रास्ते में कितने हाथी मिला ?
#
#
# Questions made on Adjective
#
# ['Case=Nom']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['NumType=Card']
# ['Case=Acc']
# ['Case=Acc']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['Mood=Ind', 'Number=Sing', 'Person=3', 'Tense=Pres', 'VerbForm=Fin', 'Voice=Act']
# कैसे कहानी एक शेखीबाज अभिमानी मक्खी की है ?
# ['Case=Nom']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['NumType=Card']
# ['Case=Acc']
# ['Case=Acc']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['Mood=Ind', 'Number=Sing', 'Person=3', 'Tense=Pres', 'VerbForm=Fin', 'Voice=Act']
# प्रस्तुत कहानी एक कैसे अभिमानी मक्खी की है ?
# ['Case=Nom']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['NumType=Card']
# ['Case=Acc']
# ['Case=Acc']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['Mood=Ind', 'Number=Sing', 'Person=3', 'Tense=Pres', 'VerbForm=Fin', 'Voice=Act']
# प्रस्तुत कहानी एक शेखीबाज कैसे मक्खी की है ?
# ['NumType=Card']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['NumType=Card']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'PronType=Prs']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['VerbForm=Conv']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Gender=Masc', 'Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Gender=Masc', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['PronType=Ind']
# ['Case=Acc', 'Gender=Masc', 'Number=Plur', 'Person=3']
# ['AdpType=Post']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Polarity=Neg', 'PronType=Neg']
# ['Gender=Masc', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin']
# ['Case=Nom', 'PronType=Prs']
# ['NumType=Card']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Aspect=Imp', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc,Gen', 'Gender=Masc', 'Number=Sing', 'Person=3', 'Poss=Yes', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Number=Sing', 'VerbForm=Inf', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc', 'Number=Plur', 'Person=3', 'PronType=Dem']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Polarity=Neg', 'PronType=Neg']
# ['Gender=Fem', 'Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Gender=Fem', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc', 'VerbForm=Inf']
# ['AdpType=Post']
# ['AdpType=Post']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['Gender=Fem', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin', 'Voice=Act']
# वह मक्खी कैसे घमंडी थी ?
# ['Case=Acc,Erg', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Acc', 'Gender=Masc', 'Number=Sing']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc', 'Number=Sing', 'VerbForm=Inf']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Case=Nom', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc,Erg', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Number=Sing', 'Person=3', 'PronType=Dem']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'PronType=Prs']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'Gender=Masc', 'VerbForm=Inf']
# ['AdpType=Post', 'Case=Acc', 'Gender=Masc']
# ['Case=Acc', 'Gender=Masc']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'PronType=Prs']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Imp', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Imp', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc,Erg', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Gender=Masc', 'Number=Plur', 'Person=3']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Number=Sing', 'Person=1', 'PronType=Prs']
# ['Aspect=Imp', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc', 'Number=Sing', 'Person=3', 'PronType=Dem']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc', 'Gender=Masc', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['VerbForm=Conv']
# ['Case=Acc,Dat', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['NumType=Card']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc,Erg', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'VerbForm=Inf']
# ['AdpType=Post']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'PronType=Prs']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'VerbForm=Inf']
# ['AdpType=Post']
# ['AdpType=Post']
# ['Case=Acc', 'Gender=Fem', 'PronType=Prs']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Dem']
# ['Case=Nom', 'Number=Plur', 'Person=3', 'PronType=Prs']
# ['AdpType=Post', 'Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Gender=Fem', 'Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Gender=Fem', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Acc,Dat', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'VerbForm=Inf']
# ['AdpType=Post']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Gender=Fem', 'Mood=Ind', 'Number=Sing', 'Tense=Past', 'VerbForm=Fin', 'Voice=Act']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['VerbForm=Conv']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Number=Sing', 'Person=2', 'Polite=Form', 'PronType=Prs']
# ['Number=Sing', 'Person=2', 'Polite=Form', 'Voice=Act']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Case=Acc,Dat', 'Number=Sing', 'Person=2', 'Polite=Form', 'PronType=Prs']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Gender=Fem', 'Number=Sing', 'Person=3', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']
# ['Mood=Ind', 'Number=Sing', 'Person=3', 'Tense=Pres', 'VerbForm=Fin']
# ['Case=Nom', 'Number=Sing', 'Person=2', 'Polite=Form', 'PronType=Prs']
# ['Case=Acc,Gen', 'Gender=Fem', 'Number=Sing', 'Person=3', 'Poss=Yes', 'PronType=Prs']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Number=Sing', 'Person=2', 'Polite=Form', 'Voice=Act']
# ['Mood=Sub', 'Number=Sing', 'Person=2', 'Polite=Form', 'VerbForm=Fin']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['VerbForm=Conv']
# ['Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['AdpType=Post', 'Case=Nom', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Nom', 'Number=Sing', 'Person=3', 'PronType=Prs']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing']
# ['AdpType=Post', 'Case=Nom', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part', 'Voice=Act']
# ['Case=Acc', 'Gender=Fem', 'Number=Sing', 'Person=3']
# ['AdpType=Post', 'Case=Acc', 'Gender=Masc', 'Number=Sing']
# ['Aspect=Perf', 'Gender=Masc', 'Number=Sing', 'VerbForm=Part']
# ['Case=Acc', 'Gender=Masc', 'Number=Sing', 'Person=3']
# ['AdpType=Post']
# ['Number=Sing', 'Voice=Act']
# ['Aspect=Perf', 'Gender=Fem', 'Number=Sing', 'VerbForm=Part']

# %%
import PySimpleGUI as sg
import os
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import indian
from nltk.tag import tnt
import string
import re
import stanza
from stanza.models.common.doc import Document

# Function to clean the text
def clean_text(text):
    text = re.sub(r'(\d+)', r'', text)
    text = text.replace(u'।', ' । ')
    text = text.replace(u',', '')
    text = text.replace(u'"', '')
    text = text.replace(u'(', '')
    text = text.replace(u')', '')
    text = text.replace(u'"', '')
    text = text.replace(u':', '')
    text = text.replace(u"'", '')
    text = text.replace(u"‘", '')
    text = text.replace(u"’", '')
    text = text.replace(u"''", '')
    text = text.replace(u".", '')
    text = text.replace(u"!", '')
    text = text.replace(u'“', '')
    text = text.replace(u'”', '')
    return text

# Function to generate questions from the story
def generate_questions(story_file):
    with open(story_file, 'r', encoding='utf-8') as f:
        story_text = f.read()

    cleaned_text = clean_text(story_text)

    # DEPENDENCY PARSING
    nlp = stanza.Pipeline(lang='hi', processors='depparse', depparse_pretagged=True)
    pretagged_doc = Document(cleaned_text)
    doc = nlp(pretagged_doc)

    # NOMINATIVE CASE
    questions = []
    output_list = []  # Replace this with your actual output list
    text = ""
    count = 0
    for item in output_list:
        if isinstance(item, tuple):
            count += 1

    j = 0
    i = 0
    num = 0
    marker = 0
    iter = 0

    while j < count:
        text = ""
        i = j
        flag = 0
        num = 0
        marker = 0
        for i in range(i, i + 500):
            red = 0
            if output_list[i][1] != 'PUNCT':
                properties = output_list[i][3]
                if properties is not None:
                    pairs = properties.split('|')
                    case_value = None
                    for pair in pairs:
                        key, value = pair.split('=')
                        if (key == 'Case' and value == 'Nom' and output_list[i][1] == 'NOUN') or (
                                key == 'Case' and value == 'Nom' and output_list[i][1] == 'PRON'):
                            if flag == 0:
                                if marker == iter:
                                    temp = "कौन"
                                    text += temp
                                    text += " "
                                    i = i + 1
                                    flag = 1
                                    break
                                else:
                                    text += output_list[i][0]
                                    text += " "
                                    i = i + 1
                                marker = marker + 1
                                break
                            else:
                                text += output_list[i][0]
                                text += " "
                                i = i + 1
                                num = num + 1
                                break
                        else:
                            text += output_list[i][0]
                            text += " "
                            i = i + 1
                            break
                else:
                    text += output_list[i][0]
                    text += " "
                    i = i + 1
                    num = num + 1
                    break
            else:
                text += output_list[i][0]
                text += " "
                i = i + 1
                num = num + 1
                break
        text = text.strip()
        text = text.strip(string.punctuation)
        text = text.replace('  ', ' ')
        text = text.replace('  ', ' ')
        if len(text) > 0:
            questions.append(text)
        j = j + 1




# Set the theme and element styling
sg.theme('Topanga')
sg.set_options(element_padding=(5, 5))

# Create the GUI window layout
layout = [
    [sg.Text('Hindi Fable Story Question Generator', font=('Arial', 24, 'bold'), justification='center')],
    [sg.Text('Team Name: Team DoNut Give Up', font=('Arial', 14), justification='center')],
    [sg.Text('Select Story File:', font=('Arial', 12)), sg.Input(key='-STORY_FILE-'), sg.FileBrowse()],
    [sg.Button('Generate Questions', key='-GENERATE-', size=(20, 2), font=('Arial', 12), button_color=('white', '#008080')),
     sg.Button('About Us', key='-ABOUT-', size=(10, 2), font=('Arial', 12), button_color=('white', '#800080'))],
    [sg.Output(size=(80, 20), key='-OUTPUT-', font=('Arial', 12), background_color='#FFFFFF', text_color='#000000')]
]

# Create the GUI window
window = sg.Window('Hindi Fable Story Question Generator', layout, finalize=True)

# Event loop to process GUI events
while True:
    event, values = window.read()

    # If the window is closed or the 'Exit' button is clicked, exit the loop
    if event == sg.WINDOW_CLOSED or event == 'Exit':
        break

    # If the 'Generate Questions' button is clicked, generate the questions
    if event == '-GENERATE-':
        story_file = values['-STORY_FILE-']

        # Check if the story file is provided
        if story_file:
            try:
                # Generate questions from the story
                questions = generate_questions(story_file)

                # Save the questions to the output file
                base_name = os.path.basename(story_file)
                output_file = os.path.splitext(base_name)[0] + '_questions.txt'
                with open(output_file, 'w') as f:
                    for question in questions:
                        f.write(question + '\n')

                # Display success message
                print(f'Successfully generated questions. Saved to {output_file}')
            except Exception as e:
                # Display error message
                print(f'Error generating questions: {str(e)}')
        else:
            # Display error message if no story file is provided
            print('Please select a story file')

    # If the 'About Us' button is clicked, display information about the team members
    if event == '-ABOUT-':
        about_layout = [
            [sg.Text('About Us', font=('Arial', 20, 'bold'), justification='center')],
            [sg.Image(filename='gargi_shroff.jpg', size=(100, 100)),
             sg.Image(filename='swarang_joshi.jpg', size=(100, 100)),
             sg.Image(filename='ketaki_shetye.jpg', size=(100, 100))],
            [sg.Text('Gargi Shroff - 2022114009', font=('Arial', 12)),
             sg.Text('Swarang Joshi - 2022114010', font=('Arial', 12)),
             sg.Text('Ketaki Shetye - 2022114013', font=('Arial', 12))],
            [sg.Button('Close', key='-CLOSE-', size=(10, 2), font=('Arial', 12), button_color=('white', '#800080'))]
        ]

        about_window = sg.Window('About Us', about_layout, modal=True)

        while True:
            event, values = about_window.read()
            if event == '-CLOSE-' or event == sg.WINDOW_CLOSED:
                break

        about_window.close()

window.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-f4c9150fb939> in <cell line: 1>()
# ----> 1 import PySimpleGUI as sg
#       2 import os
#       3 import requests
#       4 from bs4 import BeautifulSoup
#       5 import nltk
#
# ModuleNotFoundError: No module named 'PySimpleGUI'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install PySimpleGUI

# %%
# !pip install stanza

# %%
import os
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import indian
from nltk.tag import tnt
import string
import re
import stanza
from stanza.models.common.doc import Document

# Function to clean the text
def clean_text(text):
    text = re.sub(r'(\d+)', r'', text)
    text = text.replace(u'।', ' । ')
    text = text.replace(u',', '')
    text = text.replace(u'"', '')
    text = text.replace(u'(', '')
    text = text.replace(u')', '')
    text = text.replace(u'"', '')
    text = text.replace(u':', '')
    text = text.replace(u"'", '')
    text = text.replace(u"‘", '')
    text = text.replace(u"’", '')
    text = text.replace(u"''", '')
    text = text.replace(u".", '')
    text = text.replace(u"!", '')
    text = text.replace(u'“', '')
    text = text.replace(u'”', '')
    return text

# Function to generate questions from the story
def generate_questions(story_file):
    with open(story_file, 'r', encoding='utf-8') as f:
        story_text = f.read()

    cleaned_text = clean_text(story_text)

    # DEPENDENCY PARSING
    nlp = stanza.Pipeline(lang='hi', processors='depparse', depparse_pretagged=True)
    pretagged_doc = Document(cleaned_text)
    doc = nlp(pretagged_doc)

    # NOMINATIVE CASE
    questions = []
    output_list = []  # Replace this with your actual output list
    text = ""
    count = 0
    for item in output_list:
        if isinstance(item, tuple):
            count += 1

    j = 0
    i = 0
    num = 0
    marker = 0
    iter = 0

    while j < count:
        text = ""
        i = j
        flag = 0
        num = 0
        marker = 0
        for i in range(i, i + 500):
            red = 0
            if output_list[i][1] != 'PUNCT':
                properties = output_list[i][3]
                if properties is not None:
                    pairs = properties.split('|')
                    case_value = None
                    for pair in pairs:
                        key, value = pair.split('=')
                        if (key == 'Case' and value == 'Nom' and output_list[i][1] == 'NOUN') or (
                                key == 'Case' and value == 'Nom' and output_list[i][1] == 'PRON'):
                            if flag == 0:
                                if marker == iter:
                                    temp = "कौन"
                                    text += temp
                                    text += " "
                                    i = i + 1
                                    flag = 1
                                    break
                                else:
                                    text += output_list[i][0]
                                    text += " "
                                    i = i + 1
                                marker = marker + 1
                                break
                            else:
                                text += output_list[i][0]
                                text += " "
                                i = i + 1
                                num = num + 1
                                break
                        else:
                            text += output_list[i][0]
                            text += " "
                            i = i + 1
                            break
                else:
                    text += output_list[i][0]
                    text += " "
                    i = i + 1
                    num = num + 1
                    break
            else:
                text += output_list[i][0]
                text += " "
                i = i + 1
                num = num + 1
                break
        text = text.strip()
        text = text.strip(string.punctuation)
        text = text.replace('  ', ' ')
        text = text.replace('  ', ' ')
        if len(text) > 0:
            questions.append(text)
        j = j + 1

    # Return the generated questions
    return questions

def main():
    print('Hindi Fable Story Question Generator')
    print('Team Name: Team DoNut Give Up')
    story_file = input('Enter the path to the story file: ')

    # Check if the story file is provided
    if story_file:
        try:
            # Generate questions from the story
            questions = generate_questions(story_file)

            # Save the questions to the output file
            base_name = os.path.basename(story_file)
            output_file = os.path.splitext(base_name)[0] + '_questions.txt'
            with open(output_file, 'w') as f:
                for question in questions:
                    f.write(question + '\n')

            # Display success message
            print(f'Successfully generated questions. Saved to {output_file}')
        except Exception as e:
            # Display error message
            print(f'Error generating questions: {str(e)}')
    else:
        # Display error message if no story file is provided
        print('Please provide a path to the story file')

if __name__ == '__main__':
    main()
